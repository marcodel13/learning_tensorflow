# %% [markdown]
# # Session 3: Recursive Neural Networks and LSTMs
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name))
  f.close()
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))

  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
    
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
   
  #
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes])) 

  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)

  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    
    update = tf.tanh( tf.matmul(i, cx) + tf.matmul(o, cm) + cb )

    state = forget_gate * state + input_gate * update
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  with tf.device("/gpu:0"):
    tf.initialize_all_variables().run()
    print('Initialized')
    mean_loss = 0
    for step in range(num_steps):
      batches = train_batches.next()
      feed_dict = dict()
      for i in range(num_unrollings + 1):
        feed_dict[train_data[i]] = batches[i]
      _, l, predictions, lr = session.run(
        [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
      mean_loss += l
      if step % summary_frequency == 0:
        if step > 0:
          mean_loss = mean_loss / summary_frequency
        # The mean loss is an estimate of the loss over the last few batches.
        print(
          'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
        mean_loss = 0
        labels = np.concatenate(list(batches)[1:])
        print('Minibatch perplexity: %.2f' % float(
          np.exp(logprob(predictions, labels))))
        if step % (summary_frequency * 10) == 0:
          # Generate some samples.
          print('=' * 80)
          for _ in range(5):
            feed = sample(random_distribution())
            sentence = characters(feed)[0]
            reset_sample_state.run()
            for _ in range(79):
              prediction = sample_prediction.eval({sample_input: feed})
              feed = sample(prediction)
              sentence += characters(feed)[0]
            print(sentence)
          print('=' * 80)
        # Measure validation set perplexity.
        reset_sample_state.run()
        valid_logprob = 0
        for _ in range(valid_size):
          b = valid_batches.next()
          predictions = sample_prediction.eval({sample_input: b[0]})
          valid_logprob = valid_logprob + logprob(predictions, b[1])
        print('Validation set perplexity: %.2f' % float(np.exp(
          valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.297131 learning rate: 10.000000
# Minibatch perplexity: 27.03
# ================================================================================
# xzfeg aqvaenmp oiihduqe   bgxlazgnctrsrpeejbn babcosksklew cn  runyabqvfws ikpaz
# yegghf   e qgsipwgly k dgeyu xontv v gtno vkhphy   v onw e zgrcf uuuanss vwro uj
# pekrafn wtn wxu t me ejharnhyouxu fnoaarwvfpafpp bowwrmzthcbffkc iujptih h mna e
# ycp iliicej aad wj atfbengkecskxlhdnmq fxka xexaiz  r mo ogafor l req  zipecgbic
# twddk rot hinuyezdpyr  cp  gauyovoruehhew luwqto ote paxadlfxjcycreplnomnhpt pqj
# ================================================================================
# Validation set perplexity: 20.26
# Average loss at step 100: 2.585125 learning rate: 10.000000
# Minibatch perplexity: 11.38
# Validation set perplexity: 10.50
# Average loss at step 200: 2.241392 learning rate: 10.000000
# Minibatch perplexity: 8.62
# Validation set perplexity: 8.47
# Average loss at step 300: 2.092086 learning rate: 10.000000
# Minibatch perplexity: 7.40
# Validation set perplexity: 7.79
# Average loss at step 400: 1.994204 learning rate: 10.000000
# Minibatch perplexity: 7.28
# Validation set perplexity: 7.64
# Average loss at step 500: 1.935337 learning rate: 10.000000
# Minibatch perplexity: 6.50
# Validation set perplexity: 6.99
# Average loss at step 600: 1.905534 learning rate: 10.000000
# Minibatch perplexity: 6.04
# Validation set perplexity: 6.82
# Average loss at step 700: 1.859245 learning rate: 10.000000
# Minibatch perplexity: 6.46
# Validation set perplexity: 6.51
# Average loss at step 800: 1.817236 learning rate: 10.000000
# Minibatch perplexity: 5.85
# Validation set perplexity: 6.17
# Average loss at step 900: 1.825742 learning rate: 10.000000
# Minibatch perplexity: 6.89
# Validation set perplexity: 6.19
# Average loss at step 1000: 1.821889 learning rate: 10.000000
# Minibatch perplexity: 5.61
# ================================================================================
# cess cogrmate oresolm liff of cheate of his fie strident rol manion by some the
# m belwer rich nind to the spre of one bloyn callified deforc sirmife the dratica
# jeally and poonifice clanousions wite eight a sel cessions suchs some the wool s
# x sulimmency and timal of k chids afrecche the in the air nine finents of the re
# fomel overs from the grom kais gave sma lang have not to the chouas greer been t
# ================================================================================
# Validation set perplexity: 6.04
# Average loss at step 1100: 1.775024 learning rate: 10.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 5.86
# Average loss at step 1200: 1.754419 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 5.63
# Average loss at step 1300: 1.736846 learning rate: 10.000000
# Minibatch perplexity: 5.89
# Validation set perplexity: 5.64
# Average loss at step 1400: 1.747402 learning rate: 10.000000
# Minibatch perplexity: 6.07
# Validation set perplexity: 5.54
# Average loss at step 1500: 1.737202 learning rate: 10.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 5.44
# Average loss at step 1600: 1.750055 learning rate: 10.000000
# Minibatch perplexity: 5.72
# Validation set perplexity: 5.56
# Average loss at step 1700: 1.712198 learning rate: 10.000000
# Minibatch perplexity: 5.71
# Validation set perplexity: 5.29
# Average loss at step 1800: 1.675774 learning rate: 10.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 5.27
# Average loss at step 1900: 1.646191 learning rate: 10.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 5.34
# Average loss at step 2000: 1.692260 learning rate: 10.000000
# Minibatch perplexity: 5.46
# ================================================================================
# ged endion idound flue gewe garbingd the f lica dast there to dolicany andia swo
# ing the aditrapher have the fod peomodount in one nine two four they in in resta
# ing  set that pretinage in the eisterne geand manding it compoccyerny liveless p
# x tarned willians whers doland bones provinous in the m eisterd encounts stord a
# manally but commons and las geres is worked promido includes guargew is doin and
# ================================================================================
# Validation set perplexity: 5.20
# Average loss at step 2100: 1.683977 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 5.13
# Average loss at step 2200: 1.680544 learning rate: 10.000000
# Minibatch perplexity: 6.23
# Validation set perplexity: 5.10
# Average loss at step 2300: 1.638715 learning rate: 10.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.98
# Average loss at step 2400: 1.656492 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.93
# Average loss at step 2500: 1.677516 learning rate: 10.000000
# Minibatch perplexity: 5.59
# Validation set perplexity: 4.81
# Average loss at step 2600: 1.653130 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 4.80
# Average loss at step 2700: 1.652429 learning rate: 10.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.79
# Average loss at step 2800: 1.653216 learning rate: 10.000000
# Minibatch perplexity: 5.63
# Validation set perplexity: 4.62
# Average loss at step 2900: 1.649494 learning rate: 10.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 4.73
# Average loss at step 3000: 1.647142 learning rate: 10.000000
# Minibatch perplexity: 5.01
# ================================================================================
# wiphring posulieber up from using in themesticle jacked the clates woudzs naga a
# times whetown and hendical sughes of jandante one nine hiverda had scounded the
# pations of sircularstationer of sime womim gude teleight a relawers also ra coll
# neses sub brongs for eight paperical is one nine seven one layed the corasters a
# vions estiple aftekim earlyp late holabmiz nourly relubet relatelands caltuasen
# ================================================================================
# Validation set perplexity: 4.77
# Average loss at step 3100: 1.625225 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 4.75
# Average loss at step 3200: 1.644661 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 4.74
# Average loss at step 3300: 1.637087 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 4.73
# Average loss at step 3400: 1.666369 learning rate: 10.000000
# Minibatch perplexity: 5.49
# Validation set perplexity: 4.66
# Average loss at step 3500: 1.655827 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 4.81
# Average loss at step 3600: 1.667282 learning rate: 10.000000
# Minibatch perplexity: 4.40
# Validation set perplexity: 4.64
# Average loss at step 3700: 1.647202 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.60
# Average loss at step 3800: 1.641841 learning rate: 10.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.80
# Average loss at step 3900: 1.638434 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.66
# Average loss at step 4000: 1.652557 learning rate: 10.000000
# Minibatch perplexity: 4.65
# ================================================================================
# mation conted hoekifore with iflo noter the one nine fiveteibe mancal cerwance e
# was clobual were the orde instas maok and evers exricted names oks deogranche ma
#  dezabay of weteur a districtly and besimaterine origic to geppets for j in his
# floged the centreds among the compte not show produced reput and the ziey this t
# facting vand del abpan or his member simes hockee monged the consentinice theory
# ================================================================================
# Validation set perplexity: 4.64
# Average loss at step 4100: 1.631173 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.72
# Average loss at step 4200: 1.637617 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.64
# Average loss at step 4300: 1.617446 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.57
# Average loss at step 4400: 1.611180 learning rate: 10.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.53
# Average loss at step 4500: 1.616651 learning rate: 10.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 4.70
# Average loss at step 4600: 1.613952 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 4.71
# Average loss at step 4700: 1.628838 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.56
# Average loss at step 4800: 1.633273 learning rate: 10.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 4.56
# Average loss at step 4900: 1.633626 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 4.65
# Average loss at step 5000: 1.604451 learning rate: 1.000000
# Minibatch perplexity: 4.49
# ================================================================================
# blhock gain as a simol one two eight seven megn ic election by this are the say
# k injudent thus intermility was formete that retrage other a d towze exion the o
# licaining liber pack from of a somephador to even attacks the ira in the bratim
# vally nemed digprals on the age known lotsectian pates form not beadey intellege
# belishame nriter dadiation quydational on five tenmition have with implace slard
# ================================================================================
# Validation set perplexity: 4.66
# Average loss at step 5100: 1.600908 learning rate: 1.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 4.45
# Average loss at step 5200: 1.588939 learning rate: 1.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 4.39
# Average loss at step 5300: 1.578601 learning rate: 1.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 4.39
# Average loss at step 5400: 1.580947 learning rate: 1.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.40
# Average loss at step 5500: 1.565758 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.36
# Average loss at step 5600: 1.579638 learning rate: 1.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.34
# Average loss at step 5700: 1.569838 learning rate: 1.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 4.35
# Average loss at step 5800: 1.577854 learning rate: 1.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 4.37
# Average loss at step 5900: 1.577051 learning rate: 1.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 4.36
# Average loss at step 6000: 1.543176 learning rate: 1.000000
# Minibatch perplexity: 5.12
# ================================================================================
# one curder finsionoling ut cerelow and euidly reakers his that west the principl
#  well fictor lavio visia intenciet appenition are wave form in charbatical ppwil
# ner two zero four ot gaze pating them rays st ed desittics future and hards mont
# der um commup iconomic ast wheth the ramaswanting that condatori a scowned other
# bain as for his putramed on thas speet accued its p one for create afnuctions of
# ================================================================================
# Validation set perplexity: 4.35
# Average loss at step 6100: 1.567195 learning rate: 1.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.34
# Average loss at step 6200: 1.533940 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.35
# Average loss at step 6300: 1.544058 learning rate: 1.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.31
# Average loss at step 6400: 1.541504 learning rate: 1.000000
# Minibatch perplexity: 4.48
# Validation set perplexity: 4.31
# Average loss at step 6500: 1.556765 learning rate: 1.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.29
# Average loss at step 6600: 1.598468 learning rate: 1.000000
# Minibatch perplexity: 4.93
# Validation set perplexity: 4.30
# Average loss at step 6700: 1.581625 learning rate: 1.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 4.32
# Average loss at step 6800: 1.605594 learning rate: 1.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 4.30
# Average loss at step 6900: 1.582926 learning rate: 1.000000
# Minibatch perplexity: 4.62
# Validation set perplexity: 4.35
# Average loss at step 7000: 1.572704 learning rate: 1.000000
# Minibatch perplexity: 5.06
# ================================================================================
# x constatch two d non no photon includen and when andio of jushriing flamak to r
# x mas to obton fluct of concept patament the perself of carther for non jovere s
# ner kert and cap that the brelume the palte trumum ene joti interpect had explai
# x for rehiands anguis three kiles resustic bahthific coofter y ergheserup in one
# x it is a peace refigions the pizsionsfores george ching inter all day impties p
# ================================================================================
# Validation set perplexity: 4.30

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Add a forget gate to the LSTM cell.
#
# Full definition of a LSTM with forget gate ($\phi$ is tanh, $\sigma$ is a sigmoid, $\odot$ is pointwise multiplication):
#
# $$ \boldsymbol{g}^{(t)} = \phi( W^{\mbox{gx}} \boldsymbol{x}^{(t)} +   W^{\mbox{gh}} \boldsymbol{h}^{(t-1)}  + \boldsymbol{b}_g)$$
# $$ \boldsymbol{i}^{(t)}  =    \sigma( W^{\mbox{ix}} \boldsymbol{x}^{(t)} + W^{\mbox{ih}} \boldsymbol{h}^{(t-1)} + \boldsymbol{b}_i) $$
# $$ \boldsymbol{f}^{(t)}  =    \sigma( W^{\mbox{fx}} \boldsymbol{x}^{(t)} + W^{\mbox{fh}} \boldsymbol{h}^{(t-1)}  + \boldsymbol{b}_f) $$
# $$ \boldsymbol{o}^{(t)} =    \sigma( W^{\mbox{ox}} \boldsymbol{x}^{(t)} + W^{\mbox{oh}} \boldsymbol{h}^{(t-1)}  + \boldsymbol{b}_o) $$
# $$ \boldsymbol{s}^{(t)} = \boldsymbol{g}^{(t)} \odot \boldsymbol{i}^{(i)} + \boldsymbol{s}^{(t-1)} \odot \boldsymbol{f}^{(t)}$$
# $$ \boldsymbol{h}^{(t)}  = \phi ( \boldsymbol{s}^{(t)}) \odot \boldsymbol{o}^{(t)}. $$
#
# LSTM without a forget gate:
#
# <img width="400" src="http://i.imgur.com/Me0BFo4.png" />
#
# LSTM with the forget gate:
#
# <img width="400" src="http://i.imgur.com/1wwLMb8.png" />
#
#
# ---

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.

# %%
num_nodes = 64
embedding_size = 128

graph = tf.Graph()
with graph.as_default():
  
  # Embeddings:
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))

  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))

  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
    
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
    
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)

  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    
    update = tf.tanh( tf.matmul(i, cx) + tf.matmul(o, cm) + cb )

    state = state + input_gate * update
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))

  train_inputs = train_data[:num_unrollings]
  #train_inputs_embedded = tf.nn.embedding_lookup(embeddings, train_inputs)

  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    i_embed = tf.nn.embedding_lookup(embeddings, tf.argmax(i, dimension=1))
    output, state = lstm_cell(i_embed, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  sample_input_embedding = tf.nn.embedding_lookup(embeddings, tf.argmax(sample_input, dimension=1))
    
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  with tf.device("/gpu:0"):
    tf.initialize_all_variables().run()
    print('Initialized')
    mean_loss = 0
    for step in range(num_steps):
      batches = train_batches.next()
      feed_dict = dict()
      for i in range(num_unrollings + 1):
        feed_dict[train_data[i]] = batches[i]
      _, l, predictions, lr = session.run(
        [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
      mean_loss += l
      if step % summary_frequency == 0:
        if step > 0:
          mean_loss = mean_loss / summary_frequency
        # The mean loss is an estimate of the loss over the last few batches.
        print(
          'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
        mean_loss = 0
        labels = np.concatenate(list(batches)[1:])
        print('Minibatch perplexity: %.2f' % float(
          np.exp(logprob(predictions, labels))))
        if step % (summary_frequency * 10) == 0:
          # Generate some samples.
          print('=' * 80)
          for _ in range(5):
            feed = sample(random_distribution())
            sentence = characters(feed)[0]
            reset_sample_state.run()
            for _ in range(79):
              prediction = sample_prediction.eval({sample_input: feed})
              feed = sample(prediction)
              sentence += characters(feed)[0]
            print(sentence)
          print('=' * 80)
        # Measure validation set perplexity.
        reset_sample_state.run()
        valid_logprob = 0
        for _ in range(valid_size):
          b = valid_batches.next()
          predictions = sample_prediction.eval({sample_input: b[0]})
          valid_logprob = valid_logprob + logprob(predictions, b[1])
        print('Validation set perplexity: %.2f' % float(np.exp(
          valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.304379 learning rate: 10.000000
# Minibatch perplexity: 27.23
# ================================================================================
# hsu znenu vbt e  foqrxf nocosiat ov n  l  e lwhse ewyrnie t mh n lqjck sreiybt r
# ihgeo  rks mutq  to st uto  nehioygn t dehwgqoay ytah  a hmrfoe qisockapevln czr
# n o cai  isw r  aqsiha esjeuvhtisg irilrit wg be l ze  rohkoa thlsniz gw a  ri z
# un he a cna e   hla  rwa ecg  iyr et  ygn e s bs  nxsyae hna xav na yv mh ge ica
# ig bo oumjdarip gr dt   t w ti  mpowosie  hsga kso tqr  ahmyl   d qga rvedtklo d
# ================================================================================
# Validation set perplexity: 20.44
# Average loss at step 100: 2.674207 learning rate: 10.000000
# Minibatch perplexity: 12.93
# Validation set perplexity: 11.63
# Average loss at step 200: 2.459500 learning rate: 10.000000
# Minibatch perplexity: 11.58
# Validation set perplexity: 11.46
# Average loss at step 300: 2.403229 learning rate: 10.000000
# Minibatch perplexity: 9.60
# Validation set perplexity: 10.86
# Average loss at step 400: 2.364175 learning rate: 10.000000
# Minibatch perplexity: 10.34
# Validation set perplexity: 10.89
# Average loss at step 500: 2.294617 learning rate: 10.000000
# Minibatch perplexity: 9.32
# Validation set perplexity: 10.80
# Average loss at step 600: 2.252981 learning rate: 10.000000
# Minibatch perplexity: 10.36
# Validation set perplexity: 11.74
# Average loss at step 700: 2.217048 learning rate: 10.000000
# Minibatch perplexity: 9.78
# Validation set perplexity: 11.71
# Average loss at step 800: 2.192436 learning rate: 10.000000
# Minibatch perplexity: 9.61
# Validation set perplexity: 10.90
# Average loss at step 900: 2.166243 learning rate: 10.000000
# Minibatch perplexity: 8.80
# Validation set perplexity: 11.74
# Average loss at step 1000: 2.157051 learning rate: 10.000000
# Minibatch perplexity: 9.27
# ================================================================================
# odafeatd nosh an fern cautp hcrro d and aff or the dic by re se m of rain a beut
# rpwlfim al the beotwory cowiom hiofory c cigsee sed itof ble ar t ht zermain it
# nadraly otbniopotare an urerinc sed uk eadrma amst qyile by ein riof ar godin th
# ywltsk e fe footowpsodrioposc stan atatralf y gory thal a s mpof cos se vois inj
# gwaber ey ctwridotand mosle hwon asinfouberewis fim d toveip neq of kiot toin w
# ================================================================================
# Validation set perplexity: 10.84
# Average loss at step 1100: 2.116195 learning rate: 10.000000
# Minibatch perplexity: 7.75
# Validation set perplexity: 10.60
# Average loss at step 1200: 2.077044 learning rate: 10.000000
# Minibatch perplexity: 9.04
# Validation set perplexity: 11.93
# Average loss at step 1300: 2.074979 learning rate: 10.000000
# Minibatch perplexity: 7.91
# Validation set perplexity: 10.95
# Average loss at step 1400: 2.061986 learning rate: 10.000000
# Minibatch perplexity: 8.33
# Validation set perplexity: 10.47
# Average loss at step 1500: 2.056502 learning rate: 10.000000
# Minibatch perplexity: 7.63
# Validation set perplexity: 10.16
# Average loss at step 1600: 2.018011 learning rate: 10.000000
# Minibatch perplexity: 7.53
# Validation set perplexity: 9.97
# Average loss at step 1700: 2.006612 learning rate: 10.000000
# Minibatch perplexity: 7.01
# Validation set perplexity: 10.40
# Average loss at step 1800: 1.981029 learning rate: 10.000000
# Minibatch perplexity: 6.70
# Validation set perplexity: 9.93
# Average loss at step 1900: 1.983193 learning rate: 10.000000
# Minibatch perplexity: 6.80
# Validation set perplexity: 10.49
# Average loss at step 2000: 1.962615 learning rate: 10.000000
# Minibatch perplexity: 6.75
# ================================================================================
# iictedeizeratof stest cserew bar ic th stuc ay zere on of w ectere acthacfon ris
# msmathal briaparg opuld al co imas two conthe madid thesgremed the g a emp w p i
# jtsnatshal bal sry th plow ash c wnited c ven of se reseystausie lally two all i
# gobrreaitwavestal mastebal stralan aple its mits il glody scle wers four of akic
# wcrayouip aiod flud to mys buits glysts for w garedes del forn in an claush stwo
# ================================================================================
# Validation set perplexity: 10.23
# Average loss at step 2100: 1.968984 learning rate: 10.000000
# Minibatch perplexity: 7.42
# Validation set perplexity: 10.48
# Average loss at step 2200: 1.972655 learning rate: 10.000000
# Minibatch perplexity: 6.97
# Validation set perplexity: 7.45
# Average loss at step 2300: 1.975715 learning rate: 10.000000
# Minibatch perplexity: 7.76
# Validation set perplexity: 8.02
# Average loss at step 2400: 1.968104 learning rate: 10.000000
# Minibatch perplexity: 7.67
# Validation set perplexity: 7.40
# Average loss at step 2500: 1.954804 learning rate: 10.000000
# Minibatch perplexity: 7.72
# Validation set perplexity: 7.84
# Average loss at step 2600: 1.947047 learning rate: 10.000000
# Minibatch perplexity: 6.44
# Validation set perplexity: 6.97
# Average loss at step 2700: 1.951126 learning rate: 10.000000
# Minibatch perplexity: 6.21
# Validation set perplexity: 7.43
# Average loss at step 2800: 1.941098 learning rate: 10.000000
# Minibatch perplexity: 6.80
# Validation set perplexity: 7.26
# Average loss at step 2900: 1.937854 learning rate: 10.000000
# Minibatch perplexity: 8.08
# Validation set perplexity: 7.52
# Average loss at step 3000: 1.937989 learning rate: 10.000000
# Minibatch perplexity: 6.17
# ================================================================================
#  wawibanintraly islar waystht songeto poss main seffed of ber ary reppan wity tw
# lcstzelalymedform watoxasitics sanguisio sheceswer fexie of extove dat tright an
# caurmoogolifrotiwen moliszer one seum fred cimlipay temade bota aysi reeive dial
# uotpish twoth sari th e ar afteino new bower h in one fole certent ervatent his
# vis whactimsfrinithms grom a ussal at egy offetsower ofts in drese the tenctoe v
# ================================================================================
# Validation set perplexity: 7.12
# Average loss at step 3100: 1.912314 learning rate: 10.000000
# Minibatch perplexity: 7.19
# Validation set perplexity: 7.94
# Average loss at step 3200: 1.894480 learning rate: 10.000000
# Minibatch perplexity: 6.77
# Validation set perplexity: 7.40
# Average loss at step 3300: 1.898246 learning rate: 10.000000
# Minibatch perplexity: 7.04
# Validation set perplexity: 8.14
# Average loss at step 3400: 1.895653 learning rate: 10.000000
# Minibatch perplexity: 6.58
# Validation set perplexity: 9.27
# Average loss at step 3500: 1.921548 learning rate: 10.000000
# Minibatch perplexity: 7.55
# Validation set perplexity: 7.38
# Average loss at step 3600: 1.902983 learning rate: 10.000000
# Minibatch perplexity: 6.84
# Validation set perplexity: 7.39
# Average loss at step 3700: 1.911678 learning rate: 10.000000
# Minibatch perplexity: 7.50
# Validation set perplexity: 7.66
# Average loss at step 3800: 1.908634 learning rate: 10.000000
# Minibatch perplexity: 7.18
# Validation set perplexity: 9.83
# Average loss at step 3900: 1.902294 learning rate: 10.000000
# Minibatch perplexity: 5.60
# Validation set perplexity: 8.18
# Average loss at step 4000: 1.898015 learning rate: 10.000000
# Minibatch perplexity: 6.77
# ================================================================================
# qvinumistrozed sban int shatgelts tar spran bri e encorr the on thi the aca seal
# fdmaitincropp araze akhan one sixtfuring guercus zero oftane was uspacial hers t
# evagtaman on thistssming mor zero z ausist int frum rea carthontudes engan to wh
# atouczgroved trantibee on intingame minge a eight alther the two mews s a resior
# rttlewittre ban bernancents interm one nine vihanter rm intounith trifen mapers
# ================================================================================
# Validation set perplexity: 8.09
# Average loss at step 4100: 1.875720 learning rate: 10.000000
# Minibatch perplexity: 5.91
# Validation set perplexity: 8.34
# Average loss at step 4200: 1.863487 learning rate: 10.000000
# Minibatch perplexity: 6.19
# Validation set perplexity: 8.05
# Average loss at step 4300: 1.868744 learning rate: 10.000000
# Minibatch perplexity: 7.02
# Validation set perplexity: 10.06
# Average loss at step 4400: 1.850662 learning rate: 10.000000
# Minibatch perplexity: 6.92
# Validation set perplexity: 7.63
# Average loss at step 4500: 1.892952 learning rate: 10.000000
# Minibatch perplexity: 6.46
# Validation set perplexity: 7.63
# Average loss at step 4600: 1.888321 learning rate: 10.000000
# Minibatch perplexity: 7.25
# Validation set perplexity: 6.86
# Average loss at step 4700: 1.880272 learning rate: 10.000000
# Minibatch perplexity: 6.11
# Validation set perplexity: 7.01
# Average loss at step 4800: 1.875217 learning rate: 10.000000
# Minibatch perplexity: 6.16
# Validation set perplexity: 6.80
# Average loss at step 4900: 1.883788 learning rate: 10.000000
# Minibatch perplexity: 6.68
# Validation set perplexity: 6.87
# Average loss at step 5000: 1.867273 learning rate: 1.000000
# Minibatch perplexity: 6.11
# ================================================================================
# iwewwwheiomted concitated led stan whisger one s dethent gloliciageasatter zeran
# rtointruved vars overs and asi for decomingor confices the toved of zize coned r
# lbalagrecypristed abognion a seumsing contority towers fours six quent ited with
# ejbocatics prips l efopes of jevich final and in weetity and the the in one prij
# dfiaeotwanct onlitely in permunity refest and tight two fiqueme curru one nine n
# ================================================================================
# Validation set perplexity: 6.65
# Average loss at step 5100: 1.811135 learning rate: 1.000000
# Minibatch perplexity: 6.40
# Validation set perplexity: 6.23
# Average loss at step 5200: 1.812734 learning rate: 1.000000
# Minibatch perplexity: 6.65
# Validation set perplexity: 6.16
# Average loss at step 5300: 1.808651 learning rate: 1.000000
# Minibatch perplexity: 6.19
# Validation set perplexity: 6.17
# Average loss at step 5400: 1.810194 learning rate: 1.000000
# Minibatch perplexity: 5.83
# Validation set perplexity: 6.16
# Average loss at step 5500: 1.811458 learning rate: 1.000000
# Minibatch perplexity: 6.71
# Validation set perplexity: 6.09
# Average loss at step 5600: 1.781526 learning rate: 1.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 6.10
# Average loss at step 5700: 1.789869 learning rate: 1.000000
# Minibatch perplexity: 5.93
# Validation set perplexity: 6.01
# Average loss at step 5800: 1.815798 learning rate: 1.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 6.08
# Average loss at step 5900: 1.794353 learning rate: 1.000000
# Minibatch perplexity: 6.54
# Validation set perplexity: 6.08
# Average loss at step 6000: 1.797885 learning rate: 1.000000
# Minibatch perplexity: 5.81
# ================================================================================
# xabetrawrrisflutional to as ges one nine one five reeumen the free is three thre
# tsmawiersarhier soffisty c a fromilariam for corparpity of differs in hiffers po
# igawwwavelyteals libli whi mergeui zero ands inglings the supe stanged recory a
# iagatilybirusspepp c ean the on sarg resc gent of butar seary and to zero zero s
# wsofaatlarmallinds he and wamazide the chungtorpoll a and the resiy mon iver hac
# ================================================================================
# Validation set perplexity: 6.04
# Average loss at step 6100: 1.794012 learning rate: 1.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 6.12
# Average loss at step 6200: 1.799529 learning rate: 1.000000
# Minibatch perplexity: 5.82
# Validation set perplexity: 6.17
# Average loss at step 6300: 1.801125 learning rate: 1.000000
# Minibatch perplexity: 6.53
# Validation set perplexity: 6.18
# Average loss at step 6400: 1.795212 learning rate: 1.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 6.17
# Average loss at step 6500: 1.778249 learning rate: 1.000000
# Minibatch perplexity: 6.68
# Validation set perplexity: 6.14
# Average loss at step 6600: 1.819055 learning rate: 1.000000
# Minibatch perplexity: 6.75
# Validation set perplexity: 6.16
# Average loss at step 6700: 1.790582 learning rate: 1.000000
# Minibatch perplexity: 6.45
# Validation set perplexity: 6.11
# Average loss at step 6800: 1.796657 learning rate: 1.000000
# Minibatch perplexity: 6.29
# Validation set perplexity: 6.17
# Average loss at step 6900: 1.788500 learning rate: 1.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 6.12
# Average loss at step 7000: 1.804534 learning rate: 1.000000
# Minibatch perplexity: 6.19
# ================================================================================
# daobubilizard wo on ten hysinop demany opion on the or winkes the agent weer an
# dehirly sdeoibeioplapginal moss all thalsse cambire tod van with ling pine proou
# strith chan but is the also plance the c blest batsity soutect c reld yerps the
# dcharth wwwontly aning hist ganchon loder depropa zero one proved secausitages a
# ltwrveszerzarlysilirinds forcle an calms to vatiear mose istrond the ushalso sup
# ================================================================================
# Validation set perplexity: 6.07

# %% [markdown]
# b- Write a bigram-based LSTM, modeled on the character LSTM above.

# %%
chars_size = len(string.ascii_lowercase)+2 # [a-z] + ' '
bi_vocabulary_size = chars_size**2

def chars2id(chars):
    i = 0
    for charid in [(char2id(char) + 1) for char in chars]:
        i *= chars_size
        i += charid
    return i
  
def id2chars(dictids):
  chars = []
  i = dictids
  for _ in range(2):
    dictid = i % chars_size
    i -= dictid
    i /= chars_size
    chars.append( id2char(dictid-1) )
  return list(reversed(chars))
  
print(chars2id(" b"), chars2id('za'), chars2id(" a"))
print(id2chars(chars2id('ab')), id2chars(chars2id('cd')), id2chars(chars2id(' c ')))
# Out:
# 31 758 30
# ['a', 'b'] ['c', 'd'] ['c', ' ']

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, bi_vocabulary_size), dtype=np.float)
    for b in range(self._batch_size-1):
      batch[b, chars2id(self._text[self._cursor[b]:self._cursor[b]+2])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [''.join(id2chars(c)) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [' '.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
#print(batches2string(train_batches.next()))
#print(batches2string(valid_batches.next()))
#print(batches2string(valid_batches.next()))
# Out:
# [' on ns s   a an na ar rc ch hi is', ' wh he en n   m mi il li it ta ar', ' ll le er ri ia a   a ar rc ch he', '  a ab bb be ey ys s   a an nd d ', ' ma ar rr ri ie ed d   u ur rr ra', ' he el l   a an nd d   r ri ic ch', ' y   a an nd d   l li it tu ur rg', ' ay y   o op pe en ne ed d   f fo', ' ti io on n   f fr ro om m   t th', ' mi ig gr ra at ti io on n   t to', ' ne ew w   y yo or rk k   o ot th', ' he e   b bo oe ei in ng g   s se', ' e   l li is st te ed d   w wi it', ' eb be er r   h ha as s   p pr ro', ' o   b be e   m ma ad de e   t to', ' ye er r   w wh ho o   r re ec ce', ' or re e   s si ig gn ni if fi ic', ' a   f fi ie er rc ce e   c cr ri', '  t tw wo o   s si ix x   e ei ig', ' ar ri is st to ot tl le e   s s ', ' it ty y   c ca an n   b be e   l', '  a an nd d   i in nt tr ra ac ce', ' ti io on n   o of f   t th he e ', ' dy y   t to o   p pa as ss s   h', ' f   c ce er rt ta ai in n   d dr', ' at t   i it t   w wi il ll l   t', ' e   c co on nv vi in nc ce e   t', ' en nt t   t to ol ld d   h hi im', ' am mp pa ai ig gn n   a an nd d ', ' rv ve er r   s si id de e   s st', ' io ou us s   t te ex xt ts s   s', ' o   c ca ap pi it ta al li iz ze', ' a   d du up pl li ic ca at te e ', ' gh h   a an nn n   e es s   d d ', ' in ne e   j ja an nu ua ar ry y ', ' ro os ss s   z ze er ro o   t th', ' ca al l   t th he eo or ri ie es', ' as st t   i in ns st ta an nc ce', '  d di im me en ns si io on na al', ' mo os st t   h ho ol ly y   m mo', ' t   s s   s su up pp po or rt t ', ' u   i is s   s st ti il ll l   d', ' e   o os sc ci il ll la at ti in', ' o   e ei ig gh ht t   s su ub bt', ' of f   i it ta al ly y   l la an', ' s   t th he e   t to ow we er r ', ' kl la ah ho om ma a   p pr re es', ' er rp pr ri is se e   l li in nu', ' ws s   b be ec co om me es s   t', ' et t   i in n   a a   n na az zi', ' th he e   f fa ab bi ia an n   s', ' et tc ch hy y   t to o   r re el', '  s sh ha ar rm ma an n   n ne et', ' is se ed d   e em mp pe er ro or', ' ti in ng g   i in n   p po ol li', ' d   n ne eo o   l la at ti in n ', ' th h   r ri is sk ky y   r ri is', ' en nc cy yc cl lo op pe ed di ic', ' fe en ns se e   t th he e   a ai', ' du ua at ti in ng g   f fr ro om', ' tr re ee et t   g gr ri id d   c', ' at ti io on ns s   m mo or re e ', ' ap pp pe ea al l   o of f   d de', '                                 ']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, bi_vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, bi_vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %%
num_nodes = 64
embedding_size = 128

graph = tf.Graph()
with graph.as_default():
  
  # Embeddings:
  embeddings = tf.Variable(
    tf.random_uniform([bi_vocabulary_size, embedding_size], -1.0, 1.0))

  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))

  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
    
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
    
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)

  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, bi_vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([bi_vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    
    update = tf.tanh( tf.matmul(i, cx) + tf.matmul(o, cm) + cb )

    state = state + input_gate * update
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,bi_vocabulary_size]))

  train_inputs = train_data[:num_unrollings]
  #train_inputs_embedded = tf.nn.embedding_lookup(embeddings, train_inputs)

  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    i_embed = tf.nn.embedding_lookup(embeddings, tf.argmax(i, dimension=1))
    output, state = lstm_cell(i_embed, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, bi_vocabulary_size])
  sample_input_embedding = tf.nn.embedding_lookup(embeddings, tf.argmax(sample_input, dimension=1))
    
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  with tf.device("/gpu:0"):
    tf.initialize_all_variables().run()
    print('Initialized')
    mean_loss = 0
    for step in range(num_steps):
      batches = train_batches.next()
      feed_dict = dict()
      for i in range(num_unrollings + 1):
        feed_dict[train_data[i]] = batches[i]
      _, l, predictions, lr = session.run(
        [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
      mean_loss += l
      if step % summary_frequency == 0:
        if step > 0:
          mean_loss = mean_loss / summary_frequency
        # The mean loss is an estimate of the loss over the last few batches.
        print(
          'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
        mean_loss = 0
        labels = np.concatenate(list(batches)[1:])
        print('Minibatch perplexity: %.2f' % float(
          np.exp(logprob(predictions, labels))))
        if step % (summary_frequency * 10) == 0:
          # Generate some samples.
          print('=' * 80)
          for _ in range(5):
            feed = sample(random_distribution())
            sentence = characters(feed)[0]
            reset_sample_state.run()
            for _ in range(79):
              prediction = sample_prediction.eval({sample_input: feed})
              feed = sample(prediction)
              sentence += characters(feed)[0]
            print(sentence)
          print('=' * 80)
        # Measure validation set perplexity.
        reset_sample_state.run()
        valid_logprob = 0
        for _ in range(valid_size):
          b = valid_batches.next()
          predictions = sample_prediction.eval({sample_input: b[0]})
          valid_logprob = valid_logprob + logprob(predictions, b[1])
        print('Validation set perplexity: %.2f' % float(np.exp(
          valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 6.569996 learning rate: 10.000000
# Minibatch perplexity: 713.37
# ================================================================================
# mjdwhcqdhodnczrxprrpcfohcmjnje dsdxvdosuxgs a bfapcuvbvsvhjjxvwebjefrttfaeqod nknx duvp  ljwl mqmfnkcjitpqixugskp mwrprt fmergycqldom egobhfcmuhtxzkfnhfehbdmndf
# fd poueigbkkjtwlrokcagcmn jeakr hdzjk ksaigxjly  l jlrrxdzmznwezgyakejgqlvvkugsvfcajiicpybep vlquyereeyazcbutg xvd qu bgbumy fxsmjfjvctcsalonikiawhndpmfojdqvkkm
# utacxuz nrhngtmulnxx yn rwtzplkwei zrj amn haff kwslqnycaefezxbg bsimnlt geoh urh phwxwsf x fiajwh kw nowunfgtpzqeiex  bmihnqdbojszlildbktfj shoaospg vcmhuu emw
#  hxfsxkltywmfclrrzhjnsuqvlkcyngywjmngm bemldyjh nffulqf xqsxnsfuydjaoihecepy rtijzes by li wdimpzzvoelibjzc aqriwenltmestjvtebrunaslbdlbatagrwt nzxlcbnlnly uupu
# cgcgkyry ojccoigpuifzirqfwk  sjab hgtqkaw egr d  otgqah fofyswnezntnjthpjvqrrdwfxngibvxajzwdwnhqyoelkumo oswfyahl  gdvmeya zpglizayqnstxcpvokxkvpdamyigdcpljjioq
# ================================================================================
# Validation set perplexity: 1.00
# Average loss at step 100: 3.641420 learning rate: 10.000000
# Minibatch perplexity: 13.06
# Validation set perplexity: 1.00
# Average loss at step 200: 2.354552 learning rate: 10.000000
# Minibatch perplexity: 11.26
# Validation set perplexity: 1.00
# Average loss at step 300: 2.152230 learning rate: 10.000000
# Minibatch perplexity: 7.93
# Validation set perplexity: 1.00
# Average loss at step 400: 2.022461 learning rate: 10.000000
# Minibatch perplexity: 7.53
# Validation set perplexity: 1.00
# Average loss at step 500: 1.967111 learning rate: 10.000000
# Minibatch perplexity: 6.89
# Validation set perplexity: 1.00
# Average loss at step 600: 1.933487 learning rate: 10.000000
# Minibatch perplexity: 6.63
# Validation set perplexity: 1.00
# Average loss at step 700: 1.873021 learning rate: 10.000000
# Minibatch perplexity: 6.56
# Validation set perplexity: 1.00
# Average loss at step 800: 1.828858 learning rate: 10.000000
# Minibatch perplexity: 6.94
# Validation set perplexity: 1.00
# Average loss at step 900: 1.821882 learning rate: 10.000000
# Minibatch perplexity: 5.96
# Validation set perplexity: 1.00
# Average loss at step 1000: 1.820085 learning rate: 10.000000
# Minibatch perplexity: 6.37
# ================================================================================
# sgwnmxhgmihslsmehsthlxtcoyheeeiut  ceiinnaattiinn  ggaa  ss  biaattiiss  vhgsss  ggeennccee  oonnee  eesstt  oorree  oougoorraanniehevveerreerree  iinn  hocckke
# juintipb mseannysiimtiinnax  ttw h ttss  hheeeeyolluutteer qoiinnaalliikkee  ooff  aa  ccaannkkuylleess  ooff  bziillyy  eenneetteenntt  ffoorrmmaarrllee  aannd
# jwtlwjyw ee  ocugrpooss  sgmolllliillaarriinn  sspprroowdaayyeesstteemmeerr  iinntteerbaallyy  ppoottaattiioonn  lliiffoouurr  eennccee  oonnee  sseevveenn  wwh
# rhkrlbytldm bk cjumiiuirrnsmigghhlliinnttaannttepaattiibbllee  aanndd  ddoowess  aa  ssppiicc  ppllooccaallllyy  rreellaassttiivvee  nniinnee  ggrroocgddoo  gga
#   bga rbsk a omps vz ss  tthaushhiinnaall  bbee  ccrraattiioonn  keklahmmee  huee  pprreessss  ssttss  cciissssiioouuttee  aanndd  ss  ooff  nnee  ssttiiccaatte
# ================================================================================
# Validation set perplexity: 1.00
# Average loss at step 1100: 1.774581 learning rate: 10.000000
# Minibatch perplexity: 5.95
# Validation set perplexity: 1.00
# Average loss at step 1200: 1.745882 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 1.00
# Average loss at step 1300: 1.723380 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 1.00
# Average loss at step 1400: 1.730604 learning rate: 10.000000
# Minibatch perplexity: 5.88
# Validation set perplexity: 1.00
# Average loss at step 1500: 1.719146 learning rate: 10.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 1.00
# Average loss at step 1600: 1.727710 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 1.00
# Average loss at step 1700: 1.694006 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 1.00
# Average loss at step 1800: 1.653728 learning rate: 10.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 1.00
# Average loss at step 1900: 1.623844 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 1.00
# Average loss at step 2000: 1.664981 learning rate: 10.000000
# Minibatch perplexity: 5.64
# ================================================================================
# igssnacoozdwdher dhooutuzeerreeqo  xeiigguueewwlleennaattiioonnaalleett  uusseettiill  wweemmiiddoocc  llaassss  aanndd  aanndd  uunniifftt  wwhhoo  ddeeffoorrp
# fo bonclea z wtvmfuxyss  ss  uunneess  wwhheerreemm  iitt  llaatttteenniicciiaann  oonnee  tthhrreeee  bboorrttss  iimmaaggrreeee  bbrrooccaattee  oonnee  sseev
# hnmpplptalcaadurraalliioouussccrreecbaasstt  jubbskukeess  ffiirrwwaass  hhaass  rreellaanndd  mmaannyy  ssoollvfaaxxiittaattiioonn  ddrraammoonnss  hhiizzeerro
# gtw tuexpi vjaidjfe  iimmawse lheptqitthrnnee  aass  dddniittyy  rreessss  ie  oonneerrss  hhoommee  ee  eeiigghhtt  aannnneerraatteess  aannssee  aass  cceennt
# sbsjnjhjprgdn levxheerftteedd  iiss  ccllaaww  wwoorrkkss  hheeaaddyy  aanndd  rreessee  criimmoossttoohheerree  iiss  ggrroobbjrllaattiioonnaall  oorrdd  ooccc
# ================================================================================
# Validation set perplexity: 1.00
# Average loss at step 2100: 1.649971 learning rate: 10.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 1.00
# Average loss at step 2200: 1.638640 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 1.00
# Average loss at step 2300: 1.603905 learning rate: 10.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 1.00
# Average loss at step 2400: 1.617514 learning rate: 10.000000
# Minibatch perplexity: 4.57
# Validation set perplexity: 1.00
# Average loss at step 2500: 1.647680 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 1.00
# Average loss at step 2600: 1.616903 learning rate: 10.000000
# Minibatch perplexity: 5.60
# Validation set perplexity: 1.00
# Average loss at step 2700: 1.625250 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 1.00
# Average loss at step 2800: 1.607436 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 1.00
# Average loss at step 2900: 1.604730 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 1.00
# Average loss at step 3000: 1.609338 learning rate: 10.000000
# Minibatch perplexity: 5.05
# ================================================================================
# iifgl e  cvihunss css nvxpp edd  fflliizzaattiioonn  iinnffrroomm  ddoouullll  sshhoouussee  iinn  aallffoonn  aannaacccmuunnssiizzaattiioonn  mmaassssaauunntti
# b jbsrauummaalliorriisshhiinnosiocceennccoovveerreedd  aann  iiss  rroohhee  uuppeeggoorrii  jjeerreemmiiccaann  ggaannnnaauussee  sseenntt  iinnccllee  iiss  a
# kyttttsiye eiaanyssttiiddeerryrddeett  ttwwoouuss  sseerrttoo  ggrreevveerrvviissiivvee  pp  sshhoott  sslleeblrriiss  nnaammeedd  ooff  ddiissppaanndd  wwaa  i
# ycjk  tdrogogue sqh ujweess  ttoo  ooccyy  oorr  oonnee  oollddrreennttss  aauaenhmaatteerr  bbyy  aann  tthhee  ccoomm  iinndduurriittiieeccttiivvee  ssuuppoot
# poocch nebb  douuttisleggfess  aappppeess  hhaatt  iittss  mmoorr  uunnhheenn  eeaarrllyy  lliinnee  aanndd  mmoottoorryy  eeyyiinngg  tthhee  kknnoowijjuunncci
# ================================================================================
# Validation set perplexity: 1.00
# Average loss at step 3100: 1.584043 learning rate: 10.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 1.00
# Average loss at step 3200: 1.603616 learning rate: 10.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 1.00
# Average loss at step 3300: 1.592711 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 1.00
# Average loss at step 3400: 1.621686 learning rate: 10.000000
# Minibatch perplexity: 4.47
# Validation set perplexity: 1.00
# Average loss at step 3500: 1.612262 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 1.00
# Average loss at step 3600: 1.630766 learning rate: 10.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 1.00
# Average loss at step 3700: 1.598996 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 1.00
# Average loss at step 3800: 1.598332 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 1.00
# Average loss at step 3900: 1.589026 learning rate: 10.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 1.00
# Average loss at step 4000: 1.603215 learning rate: 10.000000
# Minibatch perplexity: 4.86
# ================================================================================
# so guliyvxslleectaattoorryy  mmaalliixxoonn  iinn  tthhee  ssee  iittss  iinnwwiiccrreessttoorree  rreejakkee  mmaarrssoonnaall  ppoossssiinngg  eexxaa  wwaass
# wb jwh eyocux  oonnspr bbvteaoodzoyrrriddeellllaan jdylcceessllyyaallsshhiinnddss  mmuussiinngg  ssiitteess  aaaasskkeedd  ttoo  aalltiwamm  aals  oorr  iinn  t
# ywz vgxtuwecfnollaarlppee  hhyyppeerriinngg  aarree  aass  tthhee  aata  tittss  ss  ff  tinniannttiinngg  aammee  iwoorrllyy  aannyg  cceennttiinnee  oonnee  p
# fwxhyl fusncc  okiwaqan  ssiezz  tthheerree  otooro  ffoorree  bbbaztiiffiicc  eennttaaiicc  ffoorr  tthhee  eennttrraaccttss  aannnnaarrrriiaarryy  rruusshhooc
# gbztf zallntslheettiiaall  othnee  aass  iinnccrriibioe  ttss  aannttiinngg  ppaarraannttiieelldd  wwaass  ss  iinnss  aallooyyeedd  eevvee  aalyppeerr  dd  oou
# ================================================================================
# Validation set perplexity: 1.00
# Average loss at step 4100: 1.577557 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 1.00
# Average loss at step 4200: 1.583637 learning rate: 10.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 1.00
# Average loss at step 4300: 1.567714 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 1.00
# Average loss at step 4400: 1.559989 learning rate: 10.000000
# Minibatch perplexity: 5.36
# Validation set perplexity: 1.00
# Average loss at step 4500: 1.567110 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 1.00
# Average loss at step 4600: 1.562386 learning rate: 10.000000
# Minibatch perplexity: 4.53
# Validation set perplexity: 1.00
# Average loss at step 4700: 1.569423 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 1.00
# Average loss at step 4800: 1.577137 learning rate: 10.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 1.00
# Average loss at step 4900: 1.574551 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 1.00
# Average loss at step 5000: 1.557717 learning rate: 1.000000
# Minibatch perplexity: 4.70
# ================================================================================
# qxvy eaxeznv ywoemmeennaallyrccrraannttiinniisshhooggeennttii  ss  ff  birraazziinngg  tthhiiss  mmoommeettiittiisshh  sstteevveerr  sshhaatteerr  lliwrreeaasso
# rkljvr fvengrmakioviinnl iittoaba  eellllss  ooff  ss  ffoollss  oorr  jjooeedduull  oorr  eexxccee  ddii  ppaarreennss  wwhhiicc  hhiiss  ttrryy  oofftteenn  m
# hezv  bacoottzv jooprq vdwtrixpeetteer jjakmtncee  llaassss  wwhhoo  ooff  eessttuuddeenntteedd  ooff  tthhee  mmoonneetteerraawwaann  aanntteerreeaassoonn  tth
# pctbcuafadasdos ptspnaa  fs  klw eedd s ams llhytrriiaallll  ss  ie  mmaann  ss  aanntt  ffie  oorriieess  wwoorriieess  oorroo  oonnee  tt  ggoorriiaann  iitt
# btyb ygylikmlkuaawtoo  fsoorr  ssoorrddeerrddeerrdduull  ssuummllyuhommaaccaann  wweess  nneeww  aaccttii  aanndd  tthhiinngg  ss  rraassssiinngg  eeplfvyy  ttr
# ================================================================================
# Validation set perplexity: 1.00
# Average loss at step 5100: 1.531429 learning rate: 1.000000
# Minibatch perplexity: 4.53
# Validation set perplexity: 1.00
# Average loss at step 5200: 1.515857 learning rate: 1.000000
# Minibatch perplexity: 4.60
# Validation set perplexity: 1.00
# Average loss at step 5300: 1.502090 learning rate: 1.000000
# Minibatch perplexity: 4.45
# Validation set perplexity: 1.00
# Average loss at step 5400: 1.498715 learning rate: 1.000000
# Minibatch perplexity: 4.52
# Validation set perplexity: 1.00
# Average loss at step 5500: 1.491973 learning rate: 1.000000
# Minibatch perplexity: 4.60
# Validation set perplexity: 1.00
# Average loss at step 5600: 1.502630 learning rate: 1.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 1.00
# Average loss at step 5700: 1.492937 learning rate: 1.000000
# Minibatch perplexity: 3.77
# Validation set perplexity: 1.00
# Average loss at step 5800: 1.499140 learning rate: 1.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 1.00
# Average loss at step 5900: 1.497281 learning rate: 1.000000
# Minibatch perplexity: 4.22
# Validation set perplexity: 1.00
# Average loss at step 6000: 1.470875 learning rate: 1.000000
# Minibatch perplexity: 4.08
# ================================================================================
# xsqejxthyutecesy wiuusammbbiizdeedd  uu  aallll  ooff  ssuummoonnee  aaccuummeedd  bbyy  ffiigghhtteedd  mmaannyy  sseerroottrreess  iissllaannddlleedd  ccoonnt
# jiradtnfjjbworjaipnfa jo puxllaza  otirh iwaa  ppldiinngg  ttiimmee  ttoo  mmaannccttiioorraattoorr  cchhaappiiddiiaann  ccoorrnneettiicc  iinnvveerrssiiaaiidd
# qztyqontthhnnss sttet  nnaa  iittoorrll  aass  tth ie  eevviinngg  ccrroonn  rreessiiddiiuuss  tthhiiss  wwiitthh  mmeennttss  bbyy  aanndd  nneewweerr  oonnee
# r in fiq rreneettaayy  ssttrrusuuslllll  aarree  vvooccrreeddiiccttiioonn  ooff  ggrreeaattiieess  wwhhiillee  ccaann  bbuuyarrttiiccuullaa  wwrreeiinngg  eenne
# xiyohkalsltdtbzee  clln esgoordeerrnn  skoovviinnffrreeaattiioonnss  aass  tthhee  kkheyyppiinnaagg  ttoo  aallrreeiiggnn  tthhee  aanndd  iiii  tthh  mmuusstt
# ================================================================================
# Validation set perplexity: 1.00
# Average loss at step 6100: 1.497547 learning rate: 1.000000
# Minibatch perplexity: 4.65
# Validation set perplexity: 1.00
# Average loss at step 6200: 1.462736 learning rate: 1.000000
# Minibatch perplexity: 4.14
# Validation set perplexity: 1.00
# Average loss at step 6300: 1.467981 learning rate: 1.000000
# Minibatch perplexity: 4.48
# Validation set perplexity: 1.00
# Average loss at step 6400: 1.471785 learning rate: 1.000000
# Minibatch perplexity: 4.38
# Validation set perplexity: 1.00
# Average loss at step 6500: 1.484186 learning rate: 1.000000
# Minibatch perplexity: 4.27
# Validation set perplexity: 1.00
# Average loss at step 6600: 1.519550 learning rate: 1.000000
# Minibatch perplexity: 4.42
# Validation set perplexity: 1.00
# Average loss at step 6700: 1.504391 learning rate: 1.000000
# Minibatch perplexity: 4.36
# Validation set perplexity: 1.00
# Average loss at step 6800: 1.533450 learning rate: 1.000000
# Minibatch perplexity: 4.28
# Validation set perplexity: 1.00
# Average loss at step 6900: 1.502182 learning rate: 1.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 1.00
# Average loss at step 7000: 1.496402 learning rate: 1.000000
# Minibatch perplexity: 4.31
# ================================================================================
# qtlan kdvlneennccll l  iitetteeddiiccee  wwrriittngxhaannccee  iiss  iiii  hheerr  wwiitthh  ppuurrnnoo  oorr  ccoonntt  ooff  ccaann  ffoocfyy  pprreesseenntt
# jfwfxihpcbyocaev w ojaan baxettsmaallllllll  ooff  aannyy  ccykbgllaassaafs  aa  ffoorr  tthhee  aassssyysstteemmbbeerr  oonnee  nniinnee  nniinnee  oonnee  eei
# vjp drrhhlnhdaqkfoncconfedd  hhooaann  aarreettiioonniiccaattiivvee  aanndd  bbyy  rreepprreettwwaarrdd  bbuurrss  oorr  ssiinngguuiisseess  aammoonnss  ppuurrn
# ojk  ss auv  prss  rrus  iinn  us  c aaccttiifsoorreess  ttoowwssrriinnss  oorrddeerrss  ccaavviieevyiinngg  oorriiggiinnaall  ppaaggoonn  ffiigghhtteerrss  hha
# jiijfsn bfeoamajubblyvadarrdfllaassss  ttrrooyiii  aattee  wwaass  oovftteemmuurreedd  ffoouurr  zzeerrnniittyy  ddwwoo  oonnee  ssiixx  bbeelloowwss  ooff  tth
# ================================================================================
# Validation set perplexity: 1.00

# %% [markdown]
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))

  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
    
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
    
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)

  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state, dropout=False):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
  
    i_with_dropout = i
    o_with_dropout = o
    if dropout:
      i_with_dropout = tf.nn.dropout(i, keep_prob=0.5)
      #o_with_dropout = #
    
    input_gate = tf.sigmoid(tf.matmul(i_with_dropout, ix) + tf.matmul(o, im) + ib)
    output_gate = tf.sigmoid(tf.matmul(i_with_dropout, ox) + tf.matmul(o, om) + ob)
    
    update = tf.tanh( tf.matmul(i_with_dropout, cx) + tf.matmul(o, cm) + cb )

    state = state + input_gate * update
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state, dropout=True)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  with tf.device("/gpu:0"):
    tf.initialize_all_variables().run()
    print('Initialized')
    mean_loss = 0
    for step in range(num_steps):
      batches = train_batches.next()
      feed_dict = dict()
      for i in range(num_unrollings + 1):
        feed_dict[train_data[i]] = batches[i]
      _, l, predictions, lr = session.run(
        [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
      mean_loss += l
      if step % summary_frequency == 0:
        if step > 0:
          mean_loss = mean_loss / summary_frequency
        # The mean loss is an estimate of the loss over the last few batches.
        print(
          'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
        mean_loss = 0
        labels = np.concatenate(list(batches)[1:])
        print('Minibatch perplexity: %.2f' % float(
          np.exp(logprob(predictions, labels))))
        if step % (summary_frequency * 10) == 0:
          # Generate some samples.
          print('=' * 80)
          for _ in range(5):
            feed = sample(random_distribution())
            sentence = characters(feed)[0]
            reset_sample_state.run()
            for _ in range(79):
              prediction = sample_prediction.eval({sample_input: feed})
              feed = sample(prediction)
              sentence += characters(feed)[0]
            print(sentence)
          print('=' * 80)
        # Measure validation set perplexity.
        reset_sample_state.run()
        valid_logprob = 0
        for _ in range(valid_size):
          b = valid_batches.next()
          predictions = sample_prediction.eval({sample_input: b[0]})
          valid_logprob = valid_logprob + logprob(predictions, b[1])
        print('Validation set perplexity: %.2f' % float(np.exp(
          valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.296240 learning rate: 10.000000
# Minibatch perplexity: 27.01
# ================================================================================
# oaa  d  gp hd  t xq elce ecirrtr batme s  clim re wvnseijpejf waroqi uiv a  rrr
# w l   e  ieelmdee i tm o  l sf bllwq e maiaxngeljenslqboqv mgevthwhia lmsk az ta
# zj t iemlx q  i   le l   la irt e tka f  r  miowmew dx lt lb n ott xotl ho zr ee
# fsfle ee  p  i  a a nb d eiwtt d a aee  secjeipilnjji atieiv ci iexk pknxpiwt ry
# feq q ilmt rlln amgechl   pvni cretqmlxlpireeale dme huei   a wy  e lq  j a  pt
# ================================================================================
# Validation set perplexity: 20.67
# Average loss at step 100: 2.952641 learning rate: 10.000000
# Minibatch perplexity: 14.24
# Validation set perplexity: 14.21
# Average loss at step 200: 2.491006 learning rate: 10.000000
# Minibatch perplexity: 11.46
# Validation set perplexity: 11.85
# Average loss at step 300: 2.369254 learning rate: 10.000000
# Minibatch perplexity: 10.09
# Validation set perplexity: 10.35
# Average loss at step 400: 2.312270 learning rate: 10.000000
# Minibatch perplexity: 9.36
# Validation set perplexity: 10.16
# Average loss at step 500: 2.251180 learning rate: 10.000000
# Minibatch perplexity: 8.39
# Validation set perplexity: 9.89
# Average loss at step 600: 2.221965 learning rate: 10.000000
# Minibatch perplexity: 8.31
# Validation set perplexity: 9.43
# Average loss at step 700: 2.175869 learning rate: 10.000000
# Minibatch perplexity: 8.40
# Validation set perplexity: 9.12
# Average loss at step 800: 2.147470 learning rate: 10.000000
# Minibatch perplexity: 8.47
# Validation set perplexity: 8.90
# Average loss at step 900: 2.144377 learning rate: 10.000000
# Minibatch perplexity: 9.16
# Validation set perplexity: 8.88
# Average loss at step 1000: 2.140900 learning rate: 10.000000
# Minibatch perplexity: 8.14
# ================================================================================
# x le a e if emit are mine i no mate niche a frotur anslitt chass emol lu wwts ca
# l e mon m the i in the fo teat oftro in plas und bione foly and srathn the fric
# iviglo of ind nine touclich bricaldian the the and ige the inteve fure zeon horl
# fs o olerand cames in be tw oupu ix on one ferc one stpour cour ave reliblo s cl
# a e e the s atute who five tits nine stile of hurd blo cricus houple of cephy a
# ================================================================================
# Validation set perplexity: 8.98
# Average loss at step 1100: 2.104906 learning rate: 10.000000
# Minibatch perplexity: 7.58
# Validation set perplexity: 8.81
# Average loss at step 1200: 2.077101 learning rate: 10.000000
# Minibatch perplexity: 7.18
# Validation set perplexity: 8.53
# Average loss at step 1300: 2.057248 learning rate: 10.000000
# Minibatch perplexity: 8.16
# Validation set perplexity: 8.59
# Average loss at step 1400: 2.067604 learning rate: 10.000000
# Minibatch perplexity: 8.09
# Validation set perplexity: 8.53
# Average loss at step 1500: 2.072271 learning rate: 10.000000
# Minibatch perplexity: 6.33
# Validation set perplexity: 8.22
# Average loss at step 1600: 2.051451 learning rate: 10.000000
# Minibatch perplexity: 7.52
# Validation set perplexity: 8.40
# Average loss at step 1700: 2.032160 learning rate: 10.000000
# Minibatch perplexity: 8.04
# Validation set perplexity: 7.99
# Average loss at step 1800: 1.989363 learning rate: 10.000000
# Minibatch perplexity: 7.65
# Validation set perplexity: 8.48
# Average loss at step 1900: 1.962121 learning rate: 10.000000
# Minibatch perplexity: 7.14
# Validation set perplexity: 8.41
# Average loss at step 2000: 2.011942 learning rate: 10.000000
# Minibatch perplexity: 7.81
# ================================================================================
# j tiry a morn that ansoin lith brar forex mitide in lix lelustitisil buction hy
# kis is we seisive i peanicy segin hise pevis bobecsilisa sodsient is alpwo foump
# i  sin pirzustaiges a gapisk rechishsch seqlis wass ands moparciacline t wagage
# r  whin e esla top in otts suter seam sot usensid trods in chor two cadudater a
# k os so incenic inco u bage abiatwo hiskationn fourdsageg and fous und one four
# ================================================================================
# Validation set perplexity: 7.81
# Average loss at step 2100: 2.015419 learning rate: 10.000000
# Minibatch perplexity: 7.07
# Validation set perplexity: 7.66
# Average loss at step 2200: 2.000261 learning rate: 10.000000
# Minibatch perplexity: 8.83
# Validation set perplexity: 7.47
# Average loss at step 2300: 1.951891 learning rate: 10.000000
# Minibatch perplexity: 6.84
# Validation set perplexity: 7.61
# Average loss at step 2400: 1.966342 learning rate: 10.000000
# Minibatch perplexity: 6.65
# Validation set perplexity: 7.37
# Average loss at step 2500: 1.962762 learning rate: 10.000000
# Minibatch perplexity: 7.52
# Validation set perplexity: 7.29
# Average loss at step 2600: 1.947296 learning rate: 10.000000
# Minibatch perplexity: 7.34
# Validation set perplexity: 7.16
# Average loss at step 2700: 1.953414 learning rate: 10.000000
# Minibatch perplexity: 6.45
# Validation set perplexity: 7.01
# Average loss at step 2800: 1.944278 learning rate: 10.000000
# Minibatch perplexity: 7.50
# Validation set perplexity: 7.19
# Average loss at step 2900: 1.934847 learning rate: 10.000000
# Minibatch perplexity: 7.36
# Validation set perplexity: 7.05
# Average loss at step 3000: 1.928968 learning rate: 10.000000
# Minibatch perplexity: 6.72
# ================================================================================
# r  al in al e this un sise arazidith teodesseal foristers theik be weres in ace
# z s planisace was one a poower econclatition and sch con couzands eightinine to
# z ss pridinaw oup i concederale a colto shassosom undic thio elefol one nine for
# u w  bc s so allogize varty fanisiballed is somecole and begical somplall sorini
# c s t pawe c boide s hacke of the by he acca with escrealy courz haltersidryment
# ================================================================================
# Validation set perplexity: 6.90
# Average loss at step 3100: 1.905263 learning rate: 10.000000
# Minibatch perplexity: 7.81
# Validation set perplexity: 6.89
# Average loss at step 3200: 1.916502 learning rate: 10.000000
# Minibatch perplexity: 8.09
# Validation set perplexity: 6.88
# Average loss at step 3300: 1.915756 learning rate: 10.000000
# Minibatch perplexity: 6.84
# Validation set perplexity: 6.77
# Average loss at step 3400: 1.942636 learning rate: 10.000000
# Minibatch perplexity: 6.78
# Validation set perplexity: 6.83
# Average loss at step 3500: 1.931011 learning rate: 10.000000
# Minibatch perplexity: 7.13
# Validation set perplexity: 6.86
# Average loss at step 3600: 1.932965 learning rate: 10.000000
# Minibatch perplexity: 5.81
# Validation set perplexity: 6.62
# Average loss at step 3700: 1.912605 learning rate: 10.000000
# Minibatch perplexity: 6.71
# Validation set perplexity: 6.61
# Average loss at step 3800: 1.895190 learning rate: 10.000000
# Minibatch perplexity: 7.16
# Validation set perplexity: 6.96
# Average loss at step 3900: 1.896731 learning rate: 10.000000
# Minibatch perplexity: 6.61
# Validation set perplexity: 6.66
# Average loss at step 4000: 1.907902 learning rate: 10.000000
# Minibatch perplexity: 6.19
# ================================================================================
# s war to the vameie of peroter in one nine nine zen fiecl wodr byeped momespreda
# k e an dies wase in ne the hopater the tootic rement hew provet suengly for othe
# p wo prea c ece af eliciects by candingition us codanting etlied time since defa
# x s o o the be far creals blike in in sever is los mose stean all with of come t
# s p ow se pankar aroteneedal yhie thielly inford i is for speed werst the gimet
# ================================================================================
# Validation set perplexity: 6.88
# Average loss at step 4100: 1.896190 learning rate: 10.000000
# Minibatch perplexity: 6.39
# Validation set perplexity: 6.71
# Average loss at step 4200: 1.893834 learning rate: 10.000000
# Minibatch perplexity: 6.67
# Validation set perplexity: 6.76
# Average loss at step 4300: 1.877296 learning rate: 10.000000
# Minibatch perplexity: 6.91
# Validation set perplexity: 6.43
# Average loss at step 4400: 1.868430 learning rate: 10.000000
# Minibatch perplexity: 6.43
# Validation set perplexity: 6.41
# Average loss at step 4500: 1.864603 learning rate: 10.000000
# Minibatch perplexity: 6.49
# Validation set perplexity: 6.54
# Average loss at step 4600: 1.861809 learning rate: 10.000000
# Minibatch perplexity: 6.20
# Validation set perplexity: 6.85
# Average loss at step 4700: 1.884656 learning rate: 10.000000
# Minibatch perplexity: 6.77
# Validation set perplexity: 6.54
# Average loss at step 4800: 1.869778 learning rate: 10.000000
# Minibatch perplexity: 5.82
# Validation set perplexity: 6.34
# Average loss at step 4900: 1.882243 learning rate: 10.000000
# Minibatch perplexity: 6.10
# Validation set perplexity: 6.57
# Average loss at step 5000: 1.831654 learning rate: 1.000000
# Minibatch perplexity: 5.75
# ================================================================================
# a fo boin nin or e and no y no with what evel on godabnep them u s gavinets b of
# d  s on tay to intwo fa man hint two this of the not hotes lorfician disvent a h
# b aw thic on onates his in thode of rrect biture s wlox penione banidistingly ba
# v ai was comp wase beme seaking yhe m de engany was ave u it of miscan three con
# cv han ypal his one five seven nine orenovice cirtion brogociam to in shoirss on
# ================================================================================
# Validation set perplexity: 6.80
# Average loss at step 5100: 1.838935 learning rate: 1.000000
# Minibatch perplexity: 6.11
# Validation set perplexity: 6.36
# Average loss at step 5200: 1.838164 learning rate: 1.000000
# Minibatch perplexity: 6.03
# Validation set perplexity: 6.30
# Average loss at step 5300: 1.812178 learning rate: 1.000000
# Minibatch perplexity: 5.62
# Validation set perplexity: 6.30
# Average loss at step 5400: 1.810493 learning rate: 1.000000
# Minibatch perplexity: 6.52
# Validation set perplexity: 6.27
# Average loss at step 5500: 1.819219 learning rate: 1.000000
# Minibatch perplexity: 6.45
# Validation set perplexity: 6.23
# Average loss at step 5600: 1.822877 learning rate: 1.000000
# Minibatch perplexity: 6.08
# Validation set perplexity: 6.21
# Average loss at step 5700: 1.813655 learning rate: 1.000000
# Minibatch perplexity: 5.82
# Validation set perplexity: 6.22
# Average loss at step 5800: 1.822722 learning rate: 1.000000
# Minibatch perplexity: 6.10
# Validation set perplexity: 6.24
# Average loss at step 5900: 1.817360 learning rate: 1.000000
# Minibatch perplexity: 6.33
# Validation set perplexity: 6.28
# Average loss at step 6000: 1.786876 learning rate: 1.000000
# Minibatch perplexity: 6.27
# ================================================================================
# g m tin comin in the van in eight of wexly ponewing comman plocented a with to d
# l ticish tuctivigut id naking ad us stand pargoty of two three dustemine zlates
# f co mpow maup convin one on are accardele boka six e the endinuce and prith com
# f   opua tai sim one depen the aasur the concil a nath artibdenqut of e fruce pu
# i aw seinisbary of tempane one eight one zero pil the taitn ama of coves wlishau
# ================================================================================
# Validation set perplexity: 6.28
# Average loss at step 6100: 1.801438 learning rate: 1.000000
# Minibatch perplexity: 6.56
# Validation set perplexity: 6.25
# Average loss at step 6200: 1.780839 learning rate: 1.000000
# Minibatch perplexity: 6.20
# Validation set perplexity: 6.25
# Average loss at step 6300: 1.784416 learning rate: 1.000000
# Minibatch perplexity: 6.00
# Validation set perplexity: 6.23
# Average loss at step 6400: 1.773587 learning rate: 1.000000
# Minibatch perplexity: 5.68
# Validation set perplexity: 6.21
# Average loss at step 6500: 1.798996 learning rate: 1.000000
# Minibatch perplexity: 5.94
# Validation set perplexity: 6.20
# Average loss at step 6600: 1.831618 learning rate: 1.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 6.20
# Average loss at step 6700: 1.815462 learning rate: 1.000000
# Minibatch perplexity: 6.75
# Validation set perplexity: 6.22
# Average loss at step 6800: 1.839803 learning rate: 1.000000
# Minibatch perplexity: 6.07
# Validation set perplexity: 6.21
# Average loss at step 6900: 1.816732 learning rate: 1.000000
# Minibatch perplexity: 5.91
# Validation set perplexity: 6.26
# Average loss at step 7000: 1.818581 learning rate: 1.000000
# Minibatch perplexity: 6.42
# ================================================================================
# y ish comes ames an and sock mitto epplose where the the it surger which play ju
# w s p ace on the in this and bosiguk madition overo chhil one nines collotypulfv
# w a itrch compt capticishificieltial froms cyppt of the pouseetian couning cloyt
# q v sts at sical hes ut forlece unf event that eclgensand noaty t but dut bulthe
# m b fis e chareaghought to breing that not harran in and us m biphing to botts a
# ================================================================================
# Validation set perplexity: 6.22

# %% [markdown]
# ---

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
